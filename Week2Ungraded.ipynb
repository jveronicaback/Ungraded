# %% [markdown]
# Importing dataset

# %%
import pandas as pd
import numpy as np
airquality = pd.read_csv("http://www.brycejdietrich.com/files/airquality.csv")

# %% [markdown]
# 1. Look at the airquality and its documentation

# %%
print(airquality)
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41.0    190.0   7.4    67      5    1
# 1     36.0    118.0   8.0    72      5    2
# 2     12.0    149.0  12.6    74      5    3
# 3     18.0    313.0  11.5    62      5    4
# 4      NaN      NaN  14.3    56      5    5
# ..     ...      ...   ...   ...    ...  ...
# 148   30.0    193.0   6.9    70      9   26
# 149    NaN    145.0  13.2    77      9   27
# 150   14.0    191.0  14.3    75      9   28
# 151   18.0    131.0   8.0    76      9   29
# 152   20.0    223.0  11.5    68      9   30
#
# [153 rows x 6 columns]

# %% [markdown]
# 2. Find the mean of the numbers in the Ozone vector in the airquality dataset. What issue might you run into, and why? Resolve that issue.

# %%
print(airquality['Ozone'].mean())
#Since Python's mean() function ignores missing values automatically, there will be no issues.
# Out:
# 42.12931034482759

# %% [markdown]
# 3. What is the lowest wind speed in July (Month 7)?

# %%
print(airquality['Wind'][airquality ['Month'] == 7].min())
# Out:
# 4.1

# %% [markdown]
# 4. What was the Ozone reading on the day with the highest Temp?

# %%
print(airquality['Ozone'][airquality ['Temp'] == airquality['Temp'].max()])
# Out:
# 119    76.0
# Name: Ozone, dtype: float64

# %% [markdown]
# 5. Make a plot with the Temp vector of airquality on the y-axis. The x-axis should be the numbers 1,2,3,â,n (the total number of days/rows in airquality). In your plot, use the type="1" option (that â€™s a lowercase â€œLâ€); what does that do?

# %%
import matplotlib.pyplot as plt
plt.plot(airquality.index+1, airquality['Temp'])

# %% [markdown]
# 6. Add a new column to airquality named MonthName that is, well, the name of the month. That is, when Month is 5, MonthName should be "May" and so on.

# %%
import calendar
airquality['MonthName'] = airquality['Month'] . apply(lambda x: calendar.month_name[x])
print(airquality)
# Out:
#      Ozone  Solar.R  Wind  Temp  Month  Day  MonthName
# 0     41.0    190.0   7.4    67      5    1        May
# 1     36.0    118.0   8.0    72      5    2        May
# 2     12.0    149.0  12.6    74      5    3        May
# 3     18.0    313.0  11.5    62      5    4        May
# 4      NaN      NaN  14.3    56      5    5        May
# ..     ...      ...   ...   ...    ...  ...        ...
# 148   30.0    193.0   6.9    70      9   26  September
# 149    NaN    145.0  13.2    77      9   27  September
# 150   14.0    191.0  14.3    75      9   28  September
# 151   18.0    131.0   8.0    76      9   29  September
# 152   20.0    223.0  11.5    68      9   30  September
#
# [153 rows x 7 columns]

# %% [markdown]
# 7. Create a function that converts degrees Fahrenheit to Celcius. Use this function to create a new column in airquality named TempC based on Temp.

# %%
def FtoC(f):
    return ((f-32)*5/9)
airquality['TempC'] = FtoC(airquality['Temp'])
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day MonthName      TempC
# 0   41.0    190.0   7.4    67      5    1       May  19.444444
# 1   36.0    118.0   8.0    72      5    2       May  22.222222
# 2   12.0    149.0  12.6    74      5    3       May  23.333333
# 3   18.0    313.0  11.5    62      5    4       May  16.666667
# 4    NaN      NaN  14.3    56      5    5       May  13.333333

# %% [markdown]
# 8. Revert airquality back to its original form by removing the extra columns.

# %%
airquality = airquality.drop(columns = ['MonthName', 'TempC'])
airquality.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5
